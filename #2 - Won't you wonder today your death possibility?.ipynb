# %% [markdown]
# <a href="https://colab.research.google.com/github/IncrediblePenguinLovers/Penguin_Lovers_Portfolio/blob/main/%232%20-%20Won't%20you%20wonder%20today%20your%20death%20possibility%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

class program :

  def __init__ (self):
    self.human_name = input("input your name ~ ^^ ♪ ")
    self.possibility = []

  def death_possiblity(self):
    self.a, self.b, self.c, self.d, self.e = np.random.rand(5)
    self.possibility.extend([self.a, self.b, self.c, self.d, self.e])
    print("🆚", self.possibility)

    self.k = np.argmax(self.possibility)
    self.f = self.possibility[self.k]
    self.your_destiny = self.f / sum(self.possibility)
    return self.your_destiny

  def destiny(self):

    rand = np.random.rand()

    if self.your_destiny > rand:
      print("😒 you die")
      print("1. possibility", self.your_destiny)
      print("2. rand", rand)

    else :
      print("😉 you live")
      print("1. possibility", self.your_destiny)
      print("2. rand", rand)


program = program()
result = []

for i in range(10):
  program.death_possiblity()
  program.destiny()
  result.append(program.your_destiny)
# Out:
# input your name ~ ^^ ♪ Penguin
# 🆚 [0.7646146582598115, 0.1176281574115896, 0.9811836008223183, 0.3876497993223148, 0.5160854422127423]
# 😉 you live
# 1. possibility 0.3545812359662706
# 2. rand 0.5717451470518703
# 🆚 [0.7646146582598115, 0.1176281574115896, 0.9811836008223183, 0.3876497993223148, 0.5160854422127423, 0.8749339413281975, 0.9198413165805113, 0.9335131185084459, 0.8433775039270504, 0.29109920578031834]
# 😉 you live
# 1. possibility 0.1479931285345784
# 2. rand 0.7003309759999246
# 🆚 [0.7646146582598115, 0.1176281574115896, 0.9811836008223183, 0.3876497993223148, 0.5160854422127423, 0.8749339413281975, 0.9198413165805113, 0.9335131185084459, 0.8433775039270504, 0.29109920578031834, 0.32511659700402784, 0.03741953434099621, 0.047778005803400414, 0.9508381395403832, 0.9054937337699441]
# 😉 you live
# 1. possibility 0.11028781845387203
# 2. rand 0.37710836694836347
# ...
